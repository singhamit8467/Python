# %% [markdown]
# '''
# Sample Data from Kaggle : Online Retails
# Source : https://www.kaggle.com/datasets/rohitmahulkar/online-retails-sale-dataset
# '''

# %%
# Importing Libraries and Loading File from Location
import pandas as pd
import matplotlib.pyplot as plt
x=pd.read_csv('Online Retail.csv')

# %%
# Basic View of Retails Data
import seaborn as sns
x
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 0         536365  01-12-2010  08:26:00 AM    85123A
# 1         536365  01-12-2010  08:26:00 AM     71053
# 2         536365  01-12-2010  08:26:00 AM    84406B
# 3         536365  01-12-2010  08:26:00 AM    84029G
# 4         536365  01-12-2010  08:26:00 AM    84029E
# ...          ...         ...          ...       ...
# 541904    581587  09-12-2011  12:50:00 PM     22613
# 541905    581587  09-12-2011  12:50:00 PM     22899
# 541906    581587  09-12-2011  12:50:00 PM     23254
# 541907    581587  09-12-2011  12:50:00 PM     23255
# 541908    581587  09-12-2011  12:50:00 PM     22138
#
#                                 Description  Quantity  UnitPrice  Totalsale  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6       2.55      15.30
# 1                       WHITE METAL LANTERN         6       3.39      20.34
# 2            CREAM CUPID HEARTS COAT HANGER         8       2.75      22.00
# ...

# %%
# Null value & Data Type Check
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   InvoiceDate  541909 non-null  object
#  2   InvoiceTime  541909 non-null  object
#  3   StockCode    541909 non-null  object
#  4   Description  540455 non-null  object
#  5   Quantity     541909 non-null  int64
#  6   UnitPrice    541909 non-null  float64
#  7   Totalsale    541909 non-null  float64
#  8   CustomerID   406829 non-null  float64
#  9   Country      541909 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 41.3+ MB

# %%
x['Quantity'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 541909 entries, 0 to 541908
# Series name: Quantity
# Non-Null Count   Dtype
# --------------   -----
# 541909 non-null  int64
# dtypes: int64(1)
# memory usage: 4.1 MB

# %%
# Problem Areas Need further Investigation as Sales Quantity is -ve.
x.query('Quantity < 0')
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 141      C536379  01-12-2010  09:41:00 AM         D
# 154      C536383  01-12-2010  09:49:00 AM    35004C
# 235      C536391  01-12-2010  10:24:00 AM     22556
# 236      C536391  01-12-2010  10:24:00 AM     21984
# 237      C536391  01-12-2010  10:24:00 AM     21983
# ...          ...         ...          ...       ...
# 540449   C581490  09-12-2011  09:57:00 AM     23144
# 541541   C581499  09-12-2011  10:28:00 AM         M
# 541715   C581568  09-12-2011  11:57:00 AM     21258
# 541716   C581569  09-12-2011  11:58:00 AM     84978
# 541717   C581569  09-12-2011  11:58:00 AM     20979
#
#                              Description  Quantity  UnitPrice  Totalsale  \
# 141                             Discount        -1      27.50     -27.50
# 154      SET OF 3 COLOURED  FLYING DUCKS        -1       4.65      -4.65
# 235       PLASTERS IN TIN CIRCUS PARADE        -12       1.65     -19.80
# ...

# %%
# Use Rank for Totalsales Decision Making
x['Ranking']=x.groupby(['StockCode'])['Totalsale'].rank()

# %%
# Arranging Dataset with Descending Ranks
x.sort_values(['Ranking'],ascending=False)
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 52709     540815  11-01-2011  12:55:00 PM    85123A
# 160542    550461  18-04-2011  01:20:00 PM    85123A
# 52132     540689  11-01-2011  08:43:00 AM    85123A
# 437471    574293  03-11-2011  03:32:00 PM    85123A
# 205933    554845  26-05-2011  07:49:00 PM    85123A
# ...          ...         ...          ...       ...
# 167120    550977  21-04-2011  05:29:00 PM     85200
# 407326   C571859  19-10-2011  01:39:00 PM     84976
# 538356    581405  08-12-2011  01:50:00 PM    90214P
# 538357    581405  08-12-2011  01:50:00 PM    90214I
# 268452    560425  18-07-2011  03:15:00 PM    81950B
#
#                                Description  Quantity  UnitPrice  Totalsale  \
# 52709   WHITE HANGING HEART T-LIGHT HOLDER      1930       2.55    4921.50
# 160542  WHITE HANGING HEART T-LIGHT HOLDER      1930       2.40    4632.00
# 52132   WHITE HANGING HEART T-LIGHT HOLDER      1010       3.24    3272.40
# ...

# %%
x['Ranking'].describe()
# Out:
# count    541909.000000
# mean        217.101266
# std         259.954980
# min           1.000000
# 25%          48.500000
# 50%         127.000000
# 75%         282.500000
# max        2313.000000
# Name: Ranking, dtype: float64

# %%
# StockCode with Poor sales Numbers 
x.query('Ranking < 49')
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 19        536367  01-12-2010  08:34:00 AM     21777
# 53        536373  01-12-2010  09:02:00 AM     37370
# 70        536375  01-12-2010  09:32:00 AM     37370
# 107       536381  01-12-2010  09:41:00 AM     84854
# 113       536381  01-12-2010  09:41:00 AM     71270
# ...          ...         ...          ...       ...
# 541860    581581  09-12-2011  12:20:00 PM     23562
# 541861    581581  09-12-2011  12:20:00 PM     23561
# 541870    581585  09-12-2011  12:31:00 PM     22915
# 541881    581585  09-12-2011  12:31:00 PM     16016
# 541885    581585  09-12-2011  12:31:00 PM     21684
#
#                                 Description  Quantity  UnitPrice  Totalsale  \
# 19              RECIPE BOX WITH METAL HEART         4       7.95      31.80
# 53               RETRO COFFEE MUGS ASSORTED         6       1.06       6.36
# 70               RETRO COFFEE MUGS ASSORTED         6       1.06       6.36
# ...

# %%
# Stock Code with Good sales Numbers 
x.query('Ranking > 49')
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 0         536365  01-12-2010  08:26:00 AM    85123A
# 1         536365  01-12-2010  08:26:00 AM     71053
# 2         536365  01-12-2010  08:26:00 AM    84406B
# 3         536365  01-12-2010  08:26:00 AM    84029G
# 4         536365  01-12-2010  08:26:00 AM    84029E
# ...          ...         ...          ...       ...
# 541904    581587  09-12-2011  12:50:00 PM     22613
# 541905    581587  09-12-2011  12:50:00 PM     22899
# 541906    581587  09-12-2011  12:50:00 PM     23254
# 541907    581587  09-12-2011  12:50:00 PM     23255
# 541908    581587  09-12-2011  12:50:00 PM     22138
#
#                                 Description  Quantity  UnitPrice  Totalsale  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6       2.55      15.30
# 1                       WHITE METAL LANTERN         6       3.39      20.34
# 2            CREAM CUPID HEARTS COAT HANGER         8       2.75      22.00
# ...

# %%
# Weak TotalSale Countries Bottom(10)
x.groupby(x['Country']).sum().sort_values(['Totalsale'],ascending=True).drop(columns=['Ranking','CustomerID','UnitPrice']).head(10)
# Out:
#                       Quantity  Totalsale
# Country
# Saudi Arabia                75     131.17
# Bahrain                    260     548.40
# Czech Republic             592     707.72
# RSA                        352    1002.31
# Brazil                     356    1143.60
# European Community         497    1291.75
# Lithuania                  652    1661.06
# Lebanon                    386    1693.88
# USA                       1034    1730.92
# United Arab Emirates       982    1902.28

# %%
# Countries with Strong Overall Totalsale Number's Top(10)
x.groupby(x['Country']).sum().sort_values(['Totalsale'],ascending=False).drop(columns=['Ranking','CustomerID','UnitPrice']).head(10)
# Out:
#                 Quantity   Totalsale
# Country
# United Kingdom   4263829  8187806.36
# Netherlands       200128   284661.54
# EIRE              142637   263276.82
# Germany           117448   221698.21
# France            110480   197403.90
# Australia          83653   137077.27
# Switzerland        30325    56385.35
# Spain              26824    54774.58
# Belgium            23152    40910.96
# Sweden             35637    36595.91
